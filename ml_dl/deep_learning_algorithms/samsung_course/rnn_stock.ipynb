# %% [markdown]
# # 주가 예측 모델 구축

# %% [markdown]
# ## Dataset: 삼성전자 주가 데이터

# %% [markdown]
# ## 1. 주가 데이터 로드

# %% [markdown]
# ### 컬럼 설명
#
# - `Open`:   시가
# - `High`:   고가
# - `Low`:    저가
# - `Close`:  종가
# - `Volume`: 거래량
# - `Change`: 대비

# %%
# FinanceDataReader 미설치 시 데이터 직접 로드

import pandas as pd
samsung=pd.read_csv('./datas/samsung_stock.csv', index_col='Date')

# %%
# 주가 데이터프레임의 형태 살펴보기

display(samsung.head(5))
display(samsung.tail(5))
# Out:
#             Open  High   Low  Close  Volume    Change
# Date
# 1999-02-09  1682  1698  1657   1675  381820       NaN
# 1999-02-10  1653  1675  1604   1634  664282 -0.024478
# 1999-02-11  1661  1678  1643   1644  287590  0.006120
# 1999-02-12  1682  1751  1667   1743  403600  0.060219
# 1999-02-18  1712  1721  1682   1687  440930 -0.032129
#              Open   High    Low  Close    Volume    Change
# Date
# 2023-05-19  67800  68400  67500  68400  20349345  0.033233
# 2023-05-22  68400  69000  68000  68500  14470308  0.001462
# 2023-05-23  68500  68700  68100  68400   8561643 -0.001460
# 2023-05-24  68100  68700  68000  68500   8192896  0.001462
# 2023-05-25  69900  70000  68700  68800  14099597  0.004380

# %%
# 주가 그래프 시각화

samsung.Close.plot(grid=True)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ## 2. Data Preprocessing

# %%
# 2020-01-01 부터 2021-12-31 까지를 학습 데이터로 활용
# 2022-01-01 부터 현재까지를 테스트 데이터로 활용

train = samsung.loc[(samsung.index >= '2020-01-01') & (samsung.index < '2022-01-01')] 
test = samsung.loc[(samsung.index >= '2022-01-01')]

# %%
# 예측 모델링을 위한 X, y 정의 (X: Close를 제외한 값, Y: Close) -> Open, High, Low, Volume, Change를 이용해서 Close를 예측하는 task

X_train_org, y_train_org = train.drop(["Close","Change"], axis=1), train.Close
X_test_org, y_test_org = test.drop(["Close", "Change"], axis=1), test.Close

# %%
X_train_org
# Out:
#              Open   High    Low    Volume
# Date
# 2020-01-02  55500  56000  55000  12993228
# 2020-01-03  56000  56600  54900  15422255
# 2020-01-06  54900  55600  54600  10278951
# 2020-01-07  55700  56400  55600  10009778
# 2020-01-08  56200  57400  55900  23501171
# ...           ...    ...    ...       ...
# 2021-12-24  80200  80800  80200  12086380
# 2021-12-27  80600  80600  79800  10783368
# 2021-12-28  80200  80400  79700  18226325
# 2021-12-29  80200  80200  78500  19794795
# 2021-12-30  78900  79500  78100  14236700
#
# [496 rows x 4 columns]

# %%
y_train_org
# Out:
# Date
# 2020-01-02    55200
# 2020-01-03    55500
# 2020-01-06    55500
# 2020-01-07    55800
# 2020-01-08    56800
#               ...
# 2021-12-24    80500
# 2021-12-27    80200
# 2021-12-28    80300
# 2021-12-29    78800
# 2021-12-30    78300
# Name: Close, Length: 496, dtype: int64

# %%
X_test_org
# Out:
#              Open   High    Low    Volume
# Date
# 2022-01-03  79400  79800  78200  13502112
# 2022-01-04  78800  79200  78300  12427416
# 2022-01-05  78800  79000  76400  25470640
# 2022-01-06  76700  77600  76600  12931954
# 2022-01-07  78100  78400  77400  15163757
# ...           ...    ...    ...       ...
# 2023-05-19  67800  68400  67500  20349345
# 2023-05-22  68400  69000  68000  14470308
# 2023-05-23  68500  68700  68100   8561643
# 2023-05-24  68100  68700  68000   8192896
# 2023-05-25  69900  70000  68700  14099597
#
# [345 rows x 4 columns]

# %%
y_test_org
# Out:
# Date
# 2022-01-03    78600
# 2022-01-04    78700
# 2022-01-05    77400
# 2022-01-06    76900
# 2022-01-07    78300
#               ...
# 2023-05-19    68400
# 2023-05-22    68500
# 2023-05-23    68400
# 2023-05-24    68500
# 2023-05-25    68800
# Name: Close, Length: 345, dtype: int64

# %%
# feature scaling

from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler_X = MinMaxScaler()
X_train_arr = scaler_X.fit_transform(X_train_org)
X_test_arr = scaler_X.transform(X_test_org)

scaler_y = MinMaxScaler()
y_train_arr = scaler_y.fit_transform(y_train_org.values.reshape(-1,1))
y_test_arr = scaler_y.transform(y_test_org.values.reshape(-1,1))

# %%
# 시계열 형태의 데이터로 전환

import numpy as np

def build_timeseries_dataset(X, y, seq_length):
    X_list = []
    y_list = []
    for i in range(len(X)-seq_length):
        seq = X[i:i+seq_length]
        label = y[i+seq_length]
        
        X_list.append(seq)
        y_list.append(label)

    
    return np.array(X_list), np.array(y_list)

# %%
# 시계열 형태의 데이터로 전환

WINDOW_SIZE=10

X_train, y_train = build_timeseries_dataset(X_train_arr, y_train_arr, WINDOW_SIZE)
X_test, y_test = build_timeseries_dataset(X_test_arr, y_train_arr, WINDOW_SIZE)


print('Training shape:', X_train.shape, y_train.shape)
print('Test shape:', X_test.shape, y_test.shape)
# Out:
# Training shape: (486, 10, 4) (486, 1)
# Test shape: (335, 10, 4) (335, 1)

# %%
# numpy array를 모두 torch tensor 형태로 전환

import torch

X_train = torch.from_numpy(X_train).float()
X_test = torch.from_numpy(X_test).float()

y_train = torch.from_numpy(y_train).float()
y_test = torch.from_numpy(y_test).float()

print('Training shape:', X_train.shape, y_train.shape)
print('Test shape:', X_test.shape, y_test.shape)
# Out:
# Training shape: torch.Size([486, 10, 4]) torch.Size([486, 1])
# Test shape: torch.Size([335, 10, 4]) torch.Size([335, 1])

# %%
# Dataset 정의

from torch.utils.data import Dataset

class Dataset(Dataset):
    
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y

    def __len__(self):
    
        return len(self.X)

    def __getitem__(self, idx):

        return self.X[idx], self.Y[idx]
    
train_dataset = Dataset(X_train, y_train)
test_dataset = Dataset(X_test, y_test)

# %%
#DataLoader 정의


from torch.utils.data import DataLoader

train_loader = DataLoader(train_dataset, batch_size = 8, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size =8, shuffle=False)

# %% [markdown]
# ## 3. Model Building

# %%
# 모델 정의

import torch.nn as nn

class Net(nn.Module):
    def __init__(self, input_size, rnn_h_size, fnn_h_size):
        super(Net, self).__init__()
        
        # RNN 함수 정의
        self.rnn = nn.RNN(input_size= input_size, hidden_size=rnn_h_size, num_layers=1, batch_first=True)
        #self.rnn = nn.LSTM(input_size= input_size, hidden_size=rnn_h_size, num_layers=1, batch_first=True)
        #self.rnn = nn.GRU(input_size= input_size, hidden_size=rnn_h_size, num_layers=1, batch_first=True)

        # fully-connected layer 함수 정의
        self.fc1 = nn.Linear(rnn_h_size, fnn_h_size)
        self.fc2 = nn.Linear(fnn_h_size, 1)

        # nonlinearity - ReLU 함수 정의
        self.relu = nn.ReLU()


    
    def forward(self, x):
        
        # RNN layer 
        x, _ = self.rnn(x)
        #x, (hidden, c) = self.rnn(x)

        # fully-connected layers
        x = self.fc1(x[:,-1])
        x = self.relu(x)
        x = self.fc2(x)

        return x

# %%
input_size = X_train.shape[-1]
rnn_h_size = input_size
fnn_h_size = 128

net = Net(input_size = input_size, rnn_h_size = rnn_h_size, fnn_h_size = fnn_h_size )

# %% [markdown]
# ## 4. Define a Loss Function and Optimizer

# %%
# hyperparameter 설정

learning_rate = 1e-4
num_epochs = 200

# %%
# loss function 및 optimizer 설정

import torch.optim as optim

criterion = nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=learning_rate)

# %% [markdown]
# ## 5. Train the Network

# %%
from sklearn.metrics import mean_squared_error

# %%
# 여러 epoch을 반복하며 RNN 모델 학습

for epoch in range(num_epochs):

    running_loss = 0.0
    for i, data in enumerate(train_loader):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()


    
        # 전체 test set에 대한 RMSE, MAE, R2
        pred_list = []


    # 모델 평가 시에는 gradient 계산을 할 필요가 없음
    with torch.no_grad():
        for data in test_loader:
            sequences, labels = data
            
            # 예측값 출력
            pred = net(sequences)
            pred_list.append(pred)

    pred_list = np.vstack(pred_list)
    pred_inverse = scaler_y.inverse_transform(pred_list)

    true_labels = y_test_org[10:]

    rmse = mean_squared_error(pred_inverse, true_labels)**0.5

    print('epoch: %d, iter: %d, loss: %.6f test rmse: %.6f'%((epoch+1), i, loss.item(), rmse))
            
    
    print('%d epoch processed...'%(epoch+1))

print('Finished Training')
# Out:
# epoch: 1, iter: 60, loss: 0.265532 test rmse: 13844.967241
# 1 epoch processed...
# epoch: 2, iter: 60, loss: 0.066697 test rmse: 6599.051742
# 2 epoch processed...
# epoch: 3, iter: 60, loss: 0.040593 test rmse: 4349.321207
# 3 epoch processed...
# epoch: 4, iter: 60, loss: 0.015992 test rmse: 5502.423811
# 4 epoch processed...
# epoch: 5, iter: 60, loss: 0.021904 test rmse: 6061.940794
# 5 epoch processed...
# epoch: 6, iter: 60, loss: 0.029951 test rmse: 6169.192359
# 6 epoch processed...
# epoch: 7, iter: 60, loss: 0.022206 test rmse: 6008.634841
# 7 epoch processed...
# epoch: 8, iter: 60, loss: 0.023420 test rmse: 5827.510987
# 8 epoch processed...
# epoch: 9, iter: 60, loss: 0.032739 test rmse: 5552.531664
# 9 epoch processed...
# epoch: 10, iter: 60, loss: 0.024257 test rmse: 5545.169843
# 10 epoch processed...
# epoch: 11, iter: 60, loss: 0.020328 test rmse: 5307.203655
# 11 epoch processed...
# epoch: 12, iter: 60, loss: 0.007457 test rmse: 5177.114617
# 12 epoch processed...
# epoch: 13, iter: 60, loss: 0.012625 test rmse: 5111.478256
# 13 epoch processed...
# epoch: 14, iter: 60, loss: 0.012959 test rmse: 4695.853404
# 14 epoch processed...
# epoch: 15, iter: 60, loss: 0.008636 test rmse: 4574.349257
# 15 epoch processed...
# epoch: 16, iter: 60, loss: 0.007240 test rmse: 4317.604412
# 16 epoch processed...
# epoch: 17, iter: 60, loss: 0.005865 test rmse: 4011.460332
# 17 epoch processed...
# epoch: 18, iter: 60, loss: 0.006036 test rmse: 3942.637563
# 18 epoch processed...
# epoch: 19, iter: 60, loss: 0.007645 test rmse: 3661.356331
# 19 epoch processed...
# epoch: 20, iter: 60, loss: 0.001859 test rmse: 3330.655848
# 20 epoch processed...
# epoch: 21, iter: 60, loss: 0.002450 test rmse: 3308.729232
# 21 epoch processed...
# epoch: 22, iter: 60, loss: 0.003490 test rmse: 3045.356319
# 22 epoch processed...
# epoch: 23, iter: 60, loss: 0.002921 test rmse: 2987.899668
# 23 epoch processed...
# epoch: 24, iter: 60, loss: 0.003596 test rmse: 2805.036319
# 24 epoch processed...
# epoch: 25, iter: 60, loss: 0.001237 test rmse: 2821.168033
# 25 epoch processed...
# epoch: 26, iter: 60, loss: 0.000317 test rmse: 2619.956388
# 26 epoch processed...
# epoch: 27, iter: 60, loss: 0.002886 test rmse: 2592.101279
# 27 epoch processed...
# epoch: 28, iter: 60, loss: 0.001152 test rmse: 2348.816850
# 28 epoch processed...
# epoch: 29, iter: 60, loss: 0.006450 test rmse: 2199.697642
# 29 epoch processed...
# epoch: 30, iter: 60, loss: 0.002020 test rmse: 2359.715472
# 30 epoch processed...
# epoch: 31, iter: 60, loss: 0.000871 test rmse: 2285.682355
# 31 epoch processed...
# epoch: 32, iter: 60, loss: 0.000540 test rmse: 2031.635333
# 32 epoch processed...
# epoch: 33, iter: 60, loss: 0.000767 test rmse: 2029.986960
# 33 epoch processed...
# epoch: 34, iter: 60, loss: 0.000249 test rmse: 1852.881965
# 34 epoch processed...
# epoch: 35, iter: 60, loss: 0.001499 test rmse: 1922.939799
# 35 epoch processed...
# epoch: 36, iter: 60, loss: 0.000817 test rmse: 1844.751223
# 36 epoch processed...
# epoch: 37, iter: 60, loss: 0.001788 test rmse: 1927.576120
# 37 epoch processed...
# epoch: 38, iter: 60, loss: 0.000407 test rmse: 1663.901906
# 38 epoch processed...
# epoch: 39, iter: 60, loss: 0.002120 test rmse: 1710.616500
# 39 epoch processed...
# epoch: 40, iter: 60, loss: 0.000823 test rmse: 1689.747263
# 40 epoch processed...
# epoch: 41, iter: 60, loss: 0.000570 test rmse: 1657.890026
# 41 epoch processed...
# epoch: 42, iter: 60, loss: 0.000579 test rmse: 1714.304938
# 42 epoch processed...
# epoch: 43, iter: 60, loss: 0.000319 test rmse: 1636.124780
# 43 epoch processed...
# epoch: 44, iter: 60, loss: 0.000533 test rmse: 1663.332779
# 44 epoch processed...
# epoch: 45, iter: 60, loss: 0.001992 test rmse: 1663.118578
# 45 epoch processed...
# epoch: 46, iter: 60, loss: 0.000806 test rmse: 1429.303949
# 46 epoch processed...
# epoch: 47, iter: 60, loss: 0.000038 test rmse: 1615.054878
# 47 epoch processed...
# epoch: 48, iter: 60, loss: 0.003831 test rmse: 1466.550924
# 48 epoch processed...
# epoch: 49, iter: 60, loss: 0.000312 test rmse: 1378.659812
# 49 epoch processed...
# epoch: 50, iter: 60, loss: 0.001769 test rmse: 1361.561405
# 50 epoch processed...
# epoch: 51, iter: 60, loss: 0.000481 test rmse: 1525.059400
# 51 epoch processed...
# epoch: 52, iter: 60, loss: 0.000723 test rmse: 1290.841023
# 52 epoch processed...
# epoch: 53, iter: 60, loss: 0.000959 test rmse: 1380.540826
# 53 epoch processed...
# epoch: 54, iter: 60, loss: 0.000144 test rmse: 1407.513385
# 54 epoch processed...
# epoch: 55, iter: 60, loss: 0.000816 test rmse: 1253.185952
# 55 epoch processed...
# epoch: 56, iter: 60, loss: 0.001162 test rmse: 1310.693746
# 56 epoch processed...
# epoch: 57, iter: 60, loss: 0.000692 test rmse: 1276.585090
# 57 epoch processed...
# epoch: 58, iter: 60, loss: 0.000389 test rmse: 1480.827966
# 58 epoch processed...
# epoch: 59, iter: 60, loss: 0.000420 test rmse: 1122.811962
# 59 epoch processed...
# epoch: 60, iter: 60, loss: 0.003093 test rmse: 1194.563424
# 60 epoch processed...
# epoch: 61, iter: 60, loss: 0.001340 test rmse: 1237.370955
# 61 epoch processed...
# epoch: 62, iter: 60, loss: 0.000805 test rmse: 1290.489042
# 62 epoch processed...
# epoch: 63, iter: 60, loss: 0.000414 test rmse: 1123.535674
# 63 epoch processed...
# epoch: 64, iter: 60, loss: 0.001011 test rmse: 1213.605302
# 64 epoch processed...
# epoch: 65, iter: 60, loss: 0.001705 test rmse: 1289.375279
# 65 epoch processed...
# epoch: 66, iter: 60, loss: 0.000041 test rmse: 1141.625717
# 66 epoch processed...
# epoch: 67, iter: 60, loss: 0.000638 test rmse: 1173.324440
# 67 epoch processed...
# epoch: 68, iter: 60, loss: 0.000441 test rmse: 1130.834605
# 68 epoch processed...
# epoch: 69, iter: 60, loss: 0.001213 test rmse: 1102.851943
# 69 epoch processed...
# epoch: 70, iter: 60, loss: 0.000637 test rmse: 1122.111724
# 70 epoch processed...
# epoch: 71, iter: 60, loss: 0.001019 test rmse: 1171.954042
# 71 epoch processed...
# epoch: 72, iter: 60, loss: 0.000104 test rmse: 1258.417884
# 72 epoch processed...
# epoch: 73, iter: 60, loss: 0.000352 test rmse: 1222.670547
# 73 epoch processed...
# epoch: 74, iter: 60, loss: 0.000263 test rmse: 1121.181087
# 74 epoch processed...
# epoch: 75, iter: 60, loss: 0.001543 test rmse: 1082.955310
# 75 epoch processed...
# epoch: 76, iter: 60, loss: 0.000354 test rmse: 1095.300633
# 76 epoch processed...
# epoch: 77, iter: 60, loss: 0.000885 test rmse: 1263.151825
# 77 epoch processed...
# epoch: 78, iter: 60, loss: 0.000542 test rmse: 1166.134439
# 78 epoch processed...
# epoch: 79, iter: 60, loss: 0.001277 test rmse: 1124.003691
# 79 epoch processed...
# epoch: 80, iter: 60, loss: 0.001155 test rmse: 1208.956178
# 80 epoch processed...
# epoch: 81, iter: 60, loss: 0.000576 test rmse: 1222.396774
# 81 epoch processed...
# epoch: 82, iter: 60, loss: 0.000840 test rmse: 1093.129840
# 82 epoch processed...
# epoch: 83, iter: 60, loss: 0.000713 test rmse: 1160.060722
# 83 epoch processed...
# epoch: 84, iter: 60, loss: 0.000219 test rmse: 1180.923511
# 84 epoch processed...
# epoch: 85, iter: 60, loss: 0.001487 test rmse: 1226.679289
# 85 epoch processed...
# epoch: 86, iter: 60, loss: 0.000438 test rmse: 1186.881443
# 86 epoch processed...
# epoch: 87, iter: 60, loss: 0.000841 test rmse: 1105.411412
# 87 epoch processed...
# epoch: 88, iter: 60, loss: 0.000451 test rmse: 1183.215430
# 88 epoch processed...
# epoch: 89, iter: 60, loss: 0.000543 test rmse: 1122.205702
# 89 epoch processed...
# epoch: 90, iter: 60, loss: 0.000694 test rmse: 1114.564307
# 90 epoch processed...
# epoch: 91, iter: 60, loss: 0.000568 test rmse: 1067.783512
# 91 epoch processed...
# epoch: 92, iter: 60, loss: 0.000517 test rmse: 1156.908061
# 92 epoch processed...
# epoch: 93, iter: 60, loss: 0.001415 test rmse: 1112.210839
# 93 epoch processed...
# epoch: 94, iter: 60, loss: 0.000378 test rmse: 1055.367847
# 94 epoch processed...
# epoch: 95, iter: 60, loss: 0.001257 test rmse: 1073.145524
# 95 epoch processed...
# epoch: 96, iter: 60, loss: 0.000472 test rmse: 1071.345261
# 96 epoch processed...
# epoch: 97, iter: 60, loss: 0.000189 test rmse: 1203.201795
# 97 epoch processed...
# epoch: 98, iter: 60, loss: 0.000358 test rmse: 1050.396856
# 98 epoch processed...
# epoch: 99, iter: 60, loss: 0.002691 test rmse: 1064.295678
# 99 epoch processed...
# epoch: 100, iter: 60, loss: 0.001076 test rmse: 1047.442015
# 100 epoch processed...
# epoch: 101, iter: 60, loss: 0.001435 test rmse: 1050.106178
# 101 epoch processed...
# epoch: 102, iter: 60, loss: 0.001093 test rmse: 1049.569496
# 102 epoch processed...
# epoch: 103, iter: 60, loss: 0.001384 test rmse: 1059.463327
# 103 epoch processed...
# epoch: 104, iter: 60, loss: 0.000534 test rmse: 1074.984754
# 104 epoch processed...
# epoch: 105, iter: 60, loss: 0.001473 test rmse: 1085.770117
# 105 epoch processed...
# epoch: 106, iter: 60, loss: 0.000961 test rmse: 1085.202765
# 106 epoch processed...
# epoch: 107, iter: 60, loss: 0.000925 test rmse: 1046.603773
# 107 epoch processed...
# epoch: 108, iter: 60, loss: 0.000272 test rmse: 1112.098053
# 108 epoch processed...
# epoch: 109, iter: 60, loss: 0.000275 test rmse: 1043.472386
# 109 epoch processed...
# epoch: 110, iter: 60, loss: 0.000489 test rmse: 1065.536701
# 110 epoch processed...
# epoch: 111, iter: 60, loss: 0.000279 test rmse: 1049.133257
# 111 epoch processed...
# epoch: 112, iter: 60, loss: 0.001293 test rmse: 1106.365984
# 112 epoch processed...
# epoch: 113, iter: 60, loss: 0.001425 test rmse: 1070.737096
# 113 epoch processed...
# epoch: 114, iter: 60, loss: 0.000575 test rmse: 1059.968834
# 114 epoch processed...
# epoch: 115, iter: 60, loss: 0.001520 test rmse: 1041.634295
# 115 epoch processed...
# epoch: 116, iter: 60, loss: 0.000235 test rmse: 1048.136002
# 116 epoch processed...
# epoch: 117, iter: 60, loss: 0.001264 test rmse: 1060.575740
# 117 epoch processed...
# epoch: 118, iter: 60, loss: 0.000338 test rmse: 1041.211431
# 118 epoch processed...
# epoch: 119, iter: 60, loss: 0.000494 test rmse: 1080.843193
# 119 epoch processed...
# epoch: 120, iter: 60, loss: 0.001434 test rmse: 1038.532954
# 120 epoch processed...
# epoch: 121, iter: 60, loss: 0.002059 test rmse: 1052.768281
# 121 epoch processed...
# epoch: 122, iter: 60, loss: 0.000632 test rmse: 1098.675242
# 122 epoch processed...
# epoch: 123, iter: 60, loss: 0.000328 test rmse: 1034.018011
# 123 epoch processed...
# epoch: 124, iter: 60, loss: 0.000828 test rmse: 1109.611749
# 124 epoch processed...
# epoch: 125, iter: 60, loss: 0.000402 test rmse: 1039.264261
# 125 epoch processed...
# epoch: 126, iter: 60, loss: 0.001797 test rmse: 1032.752629
# 126 epoch processed...
# epoch: 127, iter: 60, loss: 0.000389 test rmse: 1087.810258
# 127 epoch processed...
# epoch: 128, iter: 60, loss: 0.002565 test rmse: 1147.126444
# 128 epoch processed...
# epoch: 129, iter: 60, loss: 0.000744 test rmse: 1054.273646
# 129 epoch processed...
# epoch: 130, iter: 60, loss: 0.001118 test rmse: 1030.283081
# 130 epoch processed...
# epoch: 131, iter: 60, loss: 0.002018 test rmse: 1055.119557
# 131 epoch processed...
# epoch: 132, iter: 60, loss: 0.000724 test rmse: 1034.152141
# 132 epoch processed...
# epoch: 133, iter: 60, loss: 0.001541 test rmse: 1092.421775
# 133 epoch processed...
# epoch: 134, iter: 60, loss: 0.001029 test rmse: 1102.434104
# 134 epoch processed...
# epoch: 135, iter: 60, loss: 0.000565 test rmse: 1138.609424
# 135 epoch processed...
# epoch: 136, iter: 60, loss: 0.000920 test rmse: 1021.328023
# 136 epoch processed...
# epoch: 137, iter: 60, loss: 0.000188 test rmse: 1046.071546
# 137 epoch processed...
# epoch: 138, iter: 60, loss: 0.000624 test rmse: 1143.723298
# 138 epoch processed...
# epoch: 139, iter: 60, loss: 0.000304 test rmse: 1075.039355
# 139 epoch processed...
# epoch: 140, iter: 60, loss: 0.001262 test rmse: 1072.936896
# 140 epoch processed...
# epoch: 141, iter: 60, loss: 0.001290 test rmse: 1076.950358
# 141 epoch processed...
# epoch: 142, iter: 60, loss: 0.000565 test rmse: 1064.996156
# 142 epoch processed...
# epoch: 143, iter: 60, loss: 0.000291 test rmse: 1029.677473
# 143 epoch processed...
# epoch: 144, iter: 60, loss: 0.000627 test rmse: 1113.887418
# 144 epoch processed...
# epoch: 145, iter: 60, loss: 0.000155 test rmse: 1030.555297
# 145 epoch processed...
# epoch: 146, iter: 60, loss: 0.000329 test rmse: 1021.663264
# 146 epoch processed...
# epoch: 147, iter: 60, loss: 0.000372 test rmse: 1018.483789
# 147 epoch processed...
# epoch: 148, iter: 60, loss: 0.000175 test rmse: 1025.323533
# 148 epoch processed...
# epoch: 149, iter: 60, loss: 0.000353 test rmse: 1015.462922
# 149 epoch processed...
# epoch: 150, iter: 60, loss: 0.000341 test rmse: 1018.505851
# 150 epoch processed...
# epoch: 151, iter: 60, loss: 0.000732 test rmse: 1033.178403
# 151 epoch processed...
# epoch: 152, iter: 60, loss: 0.000850 test rmse: 1027.479306
# 152 epoch processed...
# epoch: 153, iter: 60, loss: 0.002466 test rmse: 1079.498612
# 153 epoch processed...
# epoch: 154, iter: 60, loss: 0.002891 test rmse: 1009.419491
# 154 epoch processed...
# epoch: 155, iter: 60, loss: 0.001423 test rmse: 1015.614291
# 155 epoch processed...
# epoch: 156, iter: 60, loss: 0.001864 test rmse: 1052.616425
# 156 epoch processed...
# epoch: 157, iter: 60, loss: 0.000348 test rmse: 1024.643626
# 157 epoch processed...
# epoch: 158, iter: 60, loss: 0.000153 test rmse: 1078.264407
# 158 epoch processed...
# epoch: 159, iter: 60, loss: 0.000297 test rmse: 1043.890183
# 159 epoch processed...
# epoch: 160, iter: 60, loss: 0.000473 test rmse: 1023.348474
# 160 epoch processed...
# epoch: 161, iter: 60, loss: 0.000174 test rmse: 1036.344300
# 161 epoch processed...
# epoch: 162, iter: 60, loss: 0.001125 test rmse: 1008.407258
# 162 epoch processed...
# epoch: 163, iter: 60, loss: 0.000843 test rmse: 1088.589976
# 163 epoch processed...
# epoch: 164, iter: 60, loss: 0.001215 test rmse: 1037.292801
# 164 epoch processed...
# epoch: 165, iter: 60, loss: 0.000962 test rmse: 1005.448147
# 165 epoch processed...
# epoch: 166, iter: 60, loss: 0.001623 test rmse: 1013.401738
# 166 epoch processed...
# epoch: 167, iter: 60, loss: 0.000600 test rmse: 1050.366194
# 167 epoch processed...
# epoch: 168, iter: 60, loss: 0.001918 test rmse: 1013.288886
# 168 epoch processed...
# epoch: 169, iter: 60, loss: 0.001307 test rmse: 1024.941346
# 169 epoch processed...
# epoch: 170, iter: 60, loss: 0.002776 test rmse: 1092.527121
# 170 epoch processed...
# epoch: 171, iter: 60, loss: 0.001396 test rmse: 1028.088754
# 171 epoch processed...
# epoch: 172, iter: 60, loss: 0.000430 test rmse: 1057.858923
# 172 epoch processed...
# epoch: 173, iter: 60, loss: 0.001103 test rmse: 1012.648042
# 173 epoch processed...
# epoch: 174, iter: 60, loss: 0.000290 test rmse: 1013.577763
# 174 epoch processed...
# epoch: 175, iter: 60, loss: 0.000601 test rmse: 1064.904771
# 175 epoch processed...
# epoch: 176, iter: 60, loss: 0.000632 test rmse: 1096.993651
# 176 epoch processed...
# epoch: 177, iter: 60, loss: 0.000857 test rmse: 1057.907913
# 177 epoch processed...
# epoch: 178, iter: 60, loss: 0.000041 test rmse: 1005.428430
# 178 epoch processed...
# epoch: 179, iter: 60, loss: 0.001148 test rmse: 1034.765601
# 179 epoch processed...
# epoch: 180, iter: 60, loss: 0.000822 test rmse: 1322.835769
# 180 epoch processed...
# epoch: 181, iter: 60, loss: 0.001301 test rmse: 1030.950253
# 181 epoch processed...
# epoch: 182, iter: 60, loss: 0.001163 test rmse: 1006.895325
# 182 epoch processed...
# epoch: 183, iter: 60, loss: 0.001378 test rmse: 1016.850421
# 183 epoch processed...
# epoch: 184, iter: 60, loss: 0.000476 test rmse: 1003.475857
# 184 epoch processed...
# epoch: 185, iter: 60, loss: 0.000563 test rmse: 1002.444052
# 185 epoch processed...
# epoch: 186, iter: 60, loss: 0.000301 test rmse: 1075.462873
# 186 epoch processed...
# epoch: 187, iter: 60, loss: 0.000626 test rmse: 1001.412421
# 187 epoch processed...
# epoch: 188, iter: 60, loss: 0.000265 test rmse: 1021.986148
# 188 epoch processed...
# epoch: 189, iter: 60, loss: 0.001353 test rmse: 1015.021673
# 189 epoch processed...
# epoch: 190, iter: 60, loss: 0.001278 test rmse: 1131.803470
# 190 epoch processed...
# epoch: 191, iter: 60, loss: 0.000619 test rmse: 1071.630518
# 191 epoch processed...
# epoch: 192, iter: 60, loss: 0.000594 test rmse: 1002.004733
# 192 epoch processed...
# epoch: 193, iter: 60, loss: 0.000377 test rmse: 1011.717329
# 193 epoch processed...
# epoch: 194, iter: 60, loss: 0.000746 test rmse: 1001.584751
# 194 epoch processed...
# epoch: 195, iter: 60, loss: 0.003295 test rmse: 997.084475
# 195 epoch processed...
# epoch: 196, iter: 60, loss: 0.001116 test rmse: 1081.839139
# 196 epoch processed...
# epoch: 197, iter: 60, loss: 0.000654 test rmse: 1122.823545
# 197 epoch processed...
# epoch: 198, iter: 60, loss: 0.001040 test rmse: 1016.894190
# 198 epoch processed...
# epoch: 199, iter: 60, loss: 0.000831 test rmse: 1014.414524
# 199 epoch processed...
# epoch: 200, iter: 60, loss: 0.000341 test rmse: 1016.603832
# 200 epoch processed...
# Finished Training

# %%
# 학습된 모델 저장하기

PATH = './samsung_stock_rnn.pth'
torch.save(net.state_dict(), PATH)

# %%
# 저장된 모델의 Parameter 불러오기

net = Net(input_size = X_train.shape[-1], rnn_h_size = rnn_h_size, fnn_h_size = fnn_h_size)
net.load_state_dict(torch.load(PATH))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## 5. Test the Network on the Test Data

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# 전체 test set에 대한 RMSE, MAE, R2

pred_list = []


# 모델 학습을 종료하였으므로 gradient 계산을 할 필요가 없음
with torch.no_grad():
    for data in test_loader:
        sequences, labels = data
        
        # 예측값 출력
        pred = net(sequences)
        pred_list.append(pred)

pred_list = np.vstack(pred_list)
pred_inverse = scaler_y.inverse_transform(pred_list)

true_labels = y_test_org[10:]

rmse = mean_squared_error(pred_inverse, true_labels)**0.5
mae = mean_absolute_error(pred_inverse, true_labels)
r2 = r2_score(pred_inverse, true_labels)

print('2023-01-01 부터 현재까지 주가에 대한 RMSE:', rmse)
print('2023-01-01 부터 현재까지 주가에 대한 MAE:', mae)
print('2023-01-01 부터 현재까지 주가에 대한 R2:', r2)
# Out:
# 2023-01-01 부터 현재까지 주가에 대한 RMSE: 1016.6038318957028
# 2023-01-01 부터 현재까지 주가에 대한 MAE: 827.6392257462686
# 2023-01-01 부터 현재까지 주가에 대한 R2: 0.9643503942925215

# %%
true_labels
# Out:
# Date
# 2022-01-17    77500
# 2022-01-18    77000
# 2022-01-19    76300
# 2022-01-20    76500
# 2022-01-21    75600
#               ...
# 2023-05-19    68400
# 2023-05-22    68500
# 2023-05-23    68400
# 2023-05-24    68500
# 2023-05-25    68800
# Name: Close, Length: 335, dtype: int64

# %%
from matplotlib import pyplot as plt

fig = plt.figure(figsize=(8,3))
plt.plot(np.arange(len(pred_inverse)), pred_inverse, label = 'pred')
plt.plot(np.arange(len(true_labels)), true_labels, label = 'true')

plt.title("prediction result plot")

plt.legend()
plt.show()
